# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col = 0)
df2 = pd.read_csv('df2')
df3 = pd.read_csv('df3', index_col = 0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins = 20, edgecolor = 'black', grid = True, figsize = (10, 7))
# Out:
# <Axes: >

# %%
# Create a hist use another methods

df1['A'].plot(kind = 'hist', bins = 30, figsize = (8, 7), edgecolor = 'black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Create area plot 

df2.plot.area(alpha = 0.4)
# Out:
# <Axes: >

# %%
df2.plot.bar(figsize = (10, 7))
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked = True, figsize = (8, 7))
# Out:
# <Axes: >

# %%
df1.plot.line( y = 'B', figsize = (12, 3), lw = 1)
# Out:
# <Axes: >

# %%
df1.plot.scatter(x = 'A', y = 'B', c = 'C', cmap = 'coolwarm')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x = 'A', y = 'B', s = df1['C']* 100, edgecolor = 'black', lw = 0.3)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/matplotlib/collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df4 = pd.DataFrame(np.random.randn(1000, 2), columns = ['A', 'B'])
df4.head()
# Out:
#           A         B
# 0 -0.028086  1.762669
# 1  1.176253  0.131835
# 2 -0.185601  0.138685
# 3 -0.271686 -0.263061
# 4 -1.050827  0.309187

# %%
df4.plot.hexbin(x = 'A', y = 'B', gridsize = 25, figsize = (10, 7))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df2.plot.density()
# Out:
# <Axes: ylabel='Density'>
